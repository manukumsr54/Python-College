# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
print(sns.__version__)
# Out:
# 0.13.2

# %% [markdown]
# ## 2. dataset in seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.get_dataset_names()
iris = sns.load_dataset("iris")
titanic = sns.load_dataset("titanic")
penguins = sns.load_dataset("penguins")
flights = sns.load_dataset("flights")
tips = sns.load_dataset("tips")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## 3. Seaborn Basic Plot Structure

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
plt.show()

# %%
sns.scatterplot(data=tips, x="total_bill",y="tip",color="purple",hue="sex")
plt.show()

# %%
sns.scatterplot(data=tips, x="total_bill",y="size",color="purple",hue="sex")
plt.show()

# %%
sns.scatterplot(
    data = flights,
    x="year",
    y = "passengers",
    hue="month"
)
plt.show()

# %%
sns.lineplot(
    data=titanic,
    x="age",
    y="fare",
    hue="survived"
)
plt.show()

# %%
sns.barplot(
    data=titanic,
    x="survived",
    y="fare",
    hue="sex"
)
plt.show()

# %%
sns.countplot(
    data=iris,
    x="species"
)
plt.show()

# %%
sns.countplot(
    data=tips,
    x="smoker"
)
plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# A histogram shows the distribution of numericals

# %%
sns.histplot(
    data=tips,
    x="total_bill"
)
plt.show()

# %%
sns.histplot(
    data=tips,
    x="total_bill",
    kde=True
)
plt.show()
